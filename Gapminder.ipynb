# %% [markdown]
# # Ricardo Akira Kato Lopes - RM552447
#
#
# ### DATABASE: Gini coefficient
#
# Gini coefficient: it shows income inequallity in a society
#
# A higher number means more innequality
#
# ### DATABASE: Average daily income, $/person/day, inflation- & proce adjusted
#
# It´s the mean daily household per capta income or consuption expediture from survey expressed in 2017 PPP (constant international dollars)
#
# ### DATABASE: Population
#
# It describes the count of population by year of each country

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_gini = pd.read_csv('gini.csv')
df_pcap = pd.read_csv('mincpcap_cppp.csv')
df_pop = pd.read_csv('pop.csv')

# %%
df_gini
# Out:
#           country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0     Afghanistan  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5  ...
# 1          Angola  57.7  57.7  57.7  57.7  57.7  57.7  57.7  57.7  57.7  ...
# 2         Albania  39.9  39.9  39.9  39.9  39.9  39.9  39.9  39.9  39.9  ...
# 3         Andorra  42.5  42.5  42.5  42.5  42.5  42.5  42.5  42.5  42.5  ...
# 4             UAE  39.8  39.8  39.8  39.8  39.8  39.8  39.8  39.7  39.7  ...
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 192         Samoa  40.7  40.7  40.7  40.7  40.7  40.7  40.7  40.7  40.7  ...
# 193         Yemen  49.8  49.8  49.8  49.8  49.8  49.8  49.8  49.8  49.8  ...
# 194  South Africa  35.2  35.2  35.2  35.2  35.2  35.2  35.2  35.2  35.2  ...
# 195        Zambia  52.1  52.1  52.1  52.1  52.1  52.1  52.1  52.1  52.1  ...
# 196      Zimbabwe  27.3  27.3  27.3  27.3  27.3  27.3  27.3  27.3  27.3  ...
#
# ...

# %%
df_pcap
# Out:
#           country   1800   1801   1802   1803   1804   1805   1806   1807  \
# 0     Afghanistan  1.330  1.330  1.330  1.330  1.330  1.330  1.330  1.330
# 1          Angola  0.779  0.781  0.785  0.789  0.791  0.795  0.799  0.802
# 2         Albania  0.919  0.921  0.924  0.927  0.929  0.932  0.935  0.937
# 3         Andorra  1.880  1.880  1.880  1.890  1.890  1.890  1.900  1.900
# 4             UAE  1.650  1.660  1.670  1.670  1.680  1.680  1.690  1.700
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 190         Samoa  4.150  4.150  4.150  4.150  4.150  4.150  4.150  4.160
# 191         Yemen  2.020  2.020  2.030  2.030  2.040  2.040  2.050  2.050
# 192  South Africa  1.760  1.740  1.720  1.710  1.690  1.600  1.600  1.730
# 193        Zambia  0.973  0.976  0.979  0.980  0.983  0.985  0.988  0.991
# 194      Zimbabwe  3.220  3.230  3.230  3.230  3.240  3.240  3.240  3.250
#
#       1808  ...    2091    2092    2093    2094    2095    2096    2097  \
# ...

# %%
df_pop
# Out:
#           country   1800   1801   1802   1803   1804   1805   1806   1807  \
# 0     Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1          Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2         Albania   400k   402k   404k   405k   407k   409k   411k   413k
# 3         Andorra   2650   2650   2650   2650   2650   2650   2650   2650
# 4             UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192         Samoa  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.2k
# 193         Yemen  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M
# 194  South Africa  1.45M  1.45M  1.46M  1.46M  1.47M  1.47M  1.48M  1.49M
# 195        Zambia   747k   758k   770k   782k   794k   806k   818k   831k
# 196      Zimbabwe  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M
#
#       1808  ...   2091   2092   2093   2094   2095   2096   2097   2098  \
# ...

# %%
df_gini.iloc[:,-1:]
# Out:
#      2050
# 0    38.2
# 1    52.0
# 2    33.7
# 3    35.0
# 4    25.9
# ..    ...
# 192  38.7
# 193  37.4
# 194  63.9
# 195  57.8
# 196  50.9
#
# [197 rows x 1 columns]

# %%
start_col = '2051'
start_idx = df_pcap.columns.get_loc(start_col)

# Get all columns from the start index to the end
columns_to_drop = df_pcap.columns[start_idx:]

# Drop these columns
df_pcap = df_pcap.drop(columns=columns_to_drop)

# %%
df_pcap
# Out:
#           country   1800   1801   1802   1803   1804   1805   1806   1807  \
# 0     Afghanistan  1.330  1.330  1.330  1.330  1.330  1.330  1.330  1.330
# 1          Angola  0.779  0.781  0.785  0.789  0.791  0.795  0.799  0.802
# 2         Albania  0.919  0.921  0.924  0.927  0.929  0.932  0.935  0.937
# 3         Andorra  1.880  1.880  1.880  1.890  1.890  1.890  1.900  1.900
# 4             UAE  1.650  1.660  1.670  1.670  1.680  1.680  1.690  1.700
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 190         Samoa  4.150  4.150  4.150  4.150  4.150  4.150  4.150  4.160
# 191         Yemen  2.020  2.020  2.030  2.030  2.040  2.040  2.050  2.050
# 192  South Africa  1.760  1.740  1.720  1.710  1.690  1.600  1.600  1.730
# 193        Zambia  0.973  0.976  0.979  0.980  0.983  0.985  0.988  0.991
# 194      Zimbabwe  3.220  3.230  3.230  3.230  3.240  3.240  3.240  3.250
#
#       1808  ...   2041   2042   2043   2044   2045   2046   2047   2048  \
# ...

# %%
countries_not_in_pcap = df_gini[~df_gini['country'].isin(df_pcap['country'])]

# Print the countries
print(countries_not_in_pcap['country'])
# Out:
# 74          Holy See
# 102    Liechtenstein
# Name: country, dtype: object

# %%
df_gini = df_gini.drop([74, 102])

# %%
countries_not_in_pcap = df_gini[~df_gini['country'].isin(df_pcap['country'])]

# Print the countries
print(countries_not_in_pcap['country'])
# Out:
# Series([], Name: country, dtype: object)

# %%
df_pcap = df_pcap.drop(df_pcap.loc[:, '1800':'1899'].columns, axis=1)

# %%
df_gini = df_gini.drop(df_gini.loc[:, '1800':'1899'].columns, axis=1)

# %%
df_pop = df_pop.drop(df_pop.loc[:, '1800':'1899'].columns, axis=1)

# %%
df_pop
# Out:
#           country   1800   1801   1802   1803   1804   1805   1806   1807  \
# 0     Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1          Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2         Albania   400k   402k   404k   405k   407k   409k   411k   413k
# 3         Andorra   2650   2650   2650   2650   2650   2650   2650   2650
# 4             UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192         Samoa  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.2k
# 193         Yemen  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M
# 194  South Africa  1.45M  1.45M  1.46M  1.46M  1.47M  1.47M  1.48M  1.49M
# 195        Zambia   747k   758k   770k   782k   794k   806k   818k   831k
# 196      Zimbabwe  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M
#
#       1808  ...   2091   2092   2093   2094   2095   2096   2097   2098  \
# ...

# %%
df_gini
# Out:
#           country  1900  1901  1902  1903  1904  1905  1906  1907  1908  ...  \
# 0     Afghanistan  39.4  39.7  40.0  40.3  40.6  40.9  41.2  41.5  41.8  ...
# 1          Angola  40.6  41.3  42.1  42.8  43.5  44.3  45.0  45.8  46.5  ...
# 2         Albania  26.5  26.4  26.4  26.4  26.4  26.3  26.3  26.3  26.3  ...
# 3         Andorra  40.6  40.6  40.5  40.5  40.5  40.5  40.4  40.4  40.4  ...
# 4             UAE  37.8  37.7  37.6  37.5  37.3  37.2  37.1  36.9  36.8  ...
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 192         Samoa  40.7  40.7  40.7  40.7  40.7  40.7  40.7  40.7  40.7  ...
# 193         Yemen  35.8  36.0  36.2  36.4  36.6  36.7  36.9  37.0  37.2  ...
# 194  South Africa  39.2  39.7  40.1  40.5  41.0  41.4  41.9  42.4  42.9  ...
# 195        Zambia  52.1  52.1  52.1  52.1  52.1  52.1  52.1  52.1  52.1  ...
# 196      Zimbabwe  29.3  29.4  29.6  29.8  29.9  30.1  30.3  30.4  30.6  ...
#
# ...

# %%
df_pcap
# Out:
#           country  1900  1901  1902  1903  1904  1905  1906  1907  1908  ...  \
# 0     Afghanistan  1.93  1.96  1.98  2.00  2.03  2.06  2.08  2.11  2.13  ...
# 1          Angola  1.21  1.21  1.22  1.22  1.23  1.23  1.24  1.24  1.25  ...
# 2         Albania  1.22  1.23  1.23  1.23  1.24  1.24  1.24  1.25  1.25  ...
# 3         Andorra  5.01  5.07  5.13  5.19  5.25  5.31  5.38  5.44  5.51  ...
# 4             UAE  3.32  3.36  3.41  3.46  3.51  3.57  3.62  3.67  3.72  ...
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 190         Samoa  5.46  5.48  5.50  5.52  5.53  5.55  5.57  5.59  5.61  ...
# 191         Yemen  2.67  2.68  2.69  2.70  2.70  2.71  2.72  2.73  2.73  ...
# 192  South Africa  1.72  1.85  2.21  2.97  2.97  3.17  3.42  3.35  2.63  ...
# 193        Zambia  1.24  1.24  1.25  1.25  1.25  1.25  1.26  1.26  1.26  ...
# 194      Zimbabwe  3.63  3.64  3.65  3.65  3.65  3.66  3.66  3.67  3.67  ...
#
# ...

# %%
countries_not_in_pcap = df_pop[~df_pop['country'].isin(df_pcap['country'])]

# Print the countries
print(countries_not_in_pcap['country'])
# Out:
# 74          Holy See
# 102    Liechtenstein
# Name: country, dtype: object

# %%
df_pop = df_pop.drop([74, 102])

# %%
start_col = '2051'
start_idx = df_pop.columns.get_loc(start_col)

# Get all columns from the start index to the end
columns_to_drop = df_pop.columns[start_idx:]

# Drop these columns
df_pop = df_pop.drop(columns=columns_to_drop)

# %%
df_pop
# Out:
#           country   1900   1901   1902   1903   1904   1905   1906   1907  \
# 0     Afghanistan  4.71M  4.75M   4.8M  4.86M  4.92M  4.98M  5.04M  5.11M
# 1          Angola   3.1M  3.08M  3.06M  3.04M  3.02M     3M  2.98M  2.96M
# 2         Albania   806k   814k   821k   828k   836k   844k   851k   859k
# 3         Andorra   4520   4550   4580   4610   4640   4670   4700   4730
# 4             UAE  48.9k  49.2k  49.6k  49.9k  50.2k  50.5k  50.8k  51.2k
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192         Samoa  35.1k  35.3k  35.7k  36.3k  36.8k  37.4k  37.9k  38.5k
# 193         Yemen  2.97M  2.98M  3.01M  3.03M  3.06M  3.09M  3.11M  3.14M
# 194  South Africa  5.16M  5.24M  5.32M  5.41M  5.51M   5.6M   5.7M  5.79M
# 195        Zambia  1.61M  1.61M   1.6M  1.59M  1.57M  1.56M  1.55M  1.54M
# 196      Zimbabwe  1.11M  1.13M  1.14M  1.16M  1.18M   1.2M  1.22M  1.24M
#
#       1908  ...   2041   2042   2043   2044   2045   2046   2047   2048  \
# ...

# %%
df_pop
# Out:
#           country   1800   1801   1802   1803   1804   1805   1806   1807  \
# 0     Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# 1          Angola  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# 2         Albania   400k   402k   404k   405k   407k   409k   411k   413k
# 3         Andorra   2650   2650   2650   2650   2650   2650   2650   2650
# 4             UAE  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 192         Samoa  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.3k  47.2k
# 193         Yemen  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M  2.59M
# 194  South Africa  1.45M  1.45M  1.46M  1.46M  1.47M  1.47M  1.48M  1.49M
# 195        Zambia   747k   758k   770k   782k   794k   806k   818k   831k
# 196      Zimbabwe  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M  1.09M
#
#       1808  ...   2041   2042   2043   2044   2045   2046   2047   2048  \
# ...

# %%
merged_countries = pd.concat([df_gini['country'], df_pcap['country']]).drop_duplicates().reset_index(drop=True)

# Create a new DataFrame with the merged 'country' column
merged_df = pd.DataFrame({'country': merged_countries})

# Print the new DataFrame
print(merged_df)
# Out:
#           country
# 0     Afghanistan
# 1          Angola
# 2         Albania
# 3         Andorra
# 4             UAE
# ..            ...
# 190         Samoa
# 191         Yemen
# 192  South Africa
# 193        Zambia
# 194      Zimbabwe
#
# [195 rows x 1 columns]

# %%
population_1900 = df_pop[['country', '1900']]
income_1900 = df_pcap[['country', '1900']]
gini_1900 = df_gini[['country', '1900']]

# Merge dataframes based on country names
merged_data = pd.merge(population_1900, income_1900, on='country')
merged_data = pd.merge(merged_data, gini_1900, on='country')
merged_data = merged_data.rename({'1900_x': 'population', '1900_y': 'income_pcap', '1900': 'gini'}, axis=1)

merged_data.dtypes
# Out:
# country         object
# population      object
# income_pcap    float64
# gini           float64
# dtype: object

# %%
def convert_population(population_str):
    if 'M' in population_str:
        # If population is in millions, remove 'M' and convert to integer
        return int(float(population_str.replace('M', '')) * 1_000_000)
    elif 'k' in population_str:
        # If population is in thousands, remove 'K' and convert to integer
        return int(float(population_str.replace('k', '')) * 1_000)
    else:
        # If population is already an integer, return it
        return int(population_str)

# Example usage:
population_int = convert_population("3.5M")  # This will return 3500000

# %%
merged_data['population'] = merged_data['population'].apply(convert_population)

# %%
merged_data['population']
# Out:
# 0      4710000
# 1      3100000
# 2       806000
# 3         4520
# 4        48900
#         ...
# 190      35100
# 191    2970000
# 192    5160000
# 193    1610000
# 194    1110000
# Name: population, Length: 195, dtype: int64

# %%
# Plot scatter plot
plt.figure(figsize=(40, 20))

# Scatter plot with population as bubble size
plt.scatter(merged_data['gini'], merged_data['income_pcap'], s=merged_data['population']*0.0001, c=range(len(merged_data)), cmap='viridis', alpha=0.7)

# Adding labels and title
plt.xlabel('Gini Coefficient (1900)')
plt.ylabel('Income per Capita (1900)')
plt.title('Scatter Plot: Gini Coefficient vs Income per Capita (1900)')

for i, txt in enumerate(merged_data['country']):
    plt.annotate(txt, (merged_data['gini'][i], merged_data['income_pcap'][i]), textcoords="offset points", xytext=(0,10), ha='center')


# Show plot
plt.grid(True)
plt.show()
